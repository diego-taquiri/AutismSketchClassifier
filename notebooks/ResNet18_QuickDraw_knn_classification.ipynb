# %% [markdown]
# # Resnet18 knn classification

# %% [markdown]
# ## Load libraries

# %%
import os
import math
from collections import Counter
import gdown
import glob

import numpy as np
import pandas as pd
import scipy
from PIL import Image as PILImage
from skimage.io import imread
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

import tensorflow.keras
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Model

from IPython.display import Image as DisplayImage

# %% [markdown]
# Clonamos el repositorio de Github con el dataset

# %%
# !git clone https://github.com/diego-taquiri/AutismSketchClassifier.git
# Out:
# Cloning into 'AutismSketchClassifier'...
# remote: Enumerating objects: 873, done.
# remote: Counting objects: 100% (873/873), done.
# remote: Compressing objects: 100% (864/864), done.
# remote: Total 873 (delta 65), reused 69 (delta 5), pack-reused 0
# Receiving objects: 100% (873/873), 6.09 MiB | 8.15 MiB/s, done.
# Resolving deltas: 100% (65/65), done.

# %% [markdown]
# Descargamos el modelo pre-entrenado

# %%
file_id = '1WZ_dmnln5-Xltfq_lOASLMPIMKjLzGWD'
output_dir = './AutismSketchClassifier/models'
output_path = os.path.join(output_dir, 'resnet18_quickdraw_pretrained.keras')
os.makedirs(output_dir, exist_ok=True)
gdown.download(f'https://drive.google.com/uc?id={file_id}', output_path, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1WZ_dmnln5-Xltfq_lOASLMPIMKjLzGWD
# From (redirected): https://drive.google.com/uc?id=1WZ_dmnln5-Xltfq_lOASLMPIMKjLzGWD&confirm=t&uuid=2586be89-3c97-458a-ac75-9ecc1b9fe479
# To: /Users/diegotaquiri/Desktop/proyectos/upch/cursos-2024-1/VS/proyecto-parcial/inference/final/AutismSketchClassifier/models/resnet18_quickdraw_pretrained.keras
# 100%|██████████| 137M/137M [00:03<00:00, 39.3MB/s]
# './AutismSketchClassifier/models/resnet18_quickdraw_pretrained.keras'

# %% [markdown]
# ## Cargar resnet18 pre-entrenada en Quick Draw dataset

# %%
model = load_model('./AutismSketchClassifier/models/resnet18_quickdraw_pretrained.keras')

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]          0         []
#
#  conv2d (Conv2D)             (None, 28, 28, 64)           640       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 28, 28, 64)           256       ['conv2d[0][0]']
#  Normalization)
#
#  re_lu (ReLU)                (None, 28, 28, 64)           0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 64)           36928     ['re_lu[0][0]']
#
#  batch_normalization_1 (Bat  (None, 28, 28, 64)           256       ['conv2d_1[0][0]']
#  chNormalization)
#
#  re_lu_1 (ReLU)              (None, 28, 28, 64)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 64)           36928     ['re_lu_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 28, 28, 64)           256       ['conv2d_2[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 28, 28, 64)           0         ['re_lu[0][0]',
#                                                                      'batch_normalization_2[0][0]'
#                                                                     ]
#
#  re_lu_2 (ReLU)              (None, 28, 28, 64)           0         ['add[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 64)           36928     ['re_lu_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 28, 28, 64)           256       ['conv2d_3[0][0]']
#  chNormalization)
#
#  re_lu_3 (ReLU)              (None, 28, 28, 64)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 28, 28, 64)           36928     ['re_lu_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 28, 28, 64)           256       ['conv2d_4[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 28, 28, 64)           0         ['re_lu_2[0][0]',
#                                                                      'batch_normalization_4[0][0]'
#                                                                     ]
#
#  re_lu_4 (ReLU)              (None, 28, 28, 64)           0         ['add_1[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 14, 14, 128)          73856     ['re_lu_4[0][0]']
#
#  batch_normalization_6 (Bat  (None, 14, 14, 128)          512       ['conv2d_6[0][0]']
#  chNormalization)
#
#  re_lu_5 (ReLU)              (None, 14, 14, 128)          0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 14, 14, 128)          8320      ['re_lu_4[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 14, 14, 128)          147584    ['re_lu_5[0][0]']
#
#  batch_normalization_5 (Bat  (None, 14, 14, 128)          512       ['conv2d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 14, 14, 128)          512       ['conv2d_7[0][0]']
#  chNormalization)
#
#  add_2 (Add)                 (None, 14, 14, 128)          0         ['batch_normalization_5[0][0]'
#                                                                     , 'batch_normalization_7[0][0]
#                                                                     ']
#
#  re_lu_6 (ReLU)              (None, 14, 14, 128)          0         ['add_2[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 14, 14, 128)          147584    ['re_lu_6[0][0]']
#
#  batch_normalization_8 (Bat  (None, 14, 14, 128)          512       ['conv2d_8[0][0]']
#  chNormalization)
#
#  re_lu_7 (ReLU)              (None, 14, 14, 128)          0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 14, 14, 128)          147584    ['re_lu_7[0][0]']
#
#  batch_normalization_9 (Bat  (None, 14, 14, 128)          512       ['conv2d_9[0][0]']
#  chNormalization)
#
#  add_3 (Add)                 (None, 14, 14, 128)          0         ['re_lu_6[0][0]',
#                                                                      'batch_normalization_9[0][0]'
#                                                                     ]
#
#  re_lu_8 (ReLU)              (None, 14, 14, 128)          0         ['add_3[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 7, 7, 256)            295168    ['re_lu_8[0][0]']
#
#  batch_normalization_11 (Ba  (None, 7, 7, 256)            1024      ['conv2d_11[0][0]']
#  tchNormalization)
#
#  re_lu_9 (ReLU)              (None, 7, 7, 256)            0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_10 (Conv2D)          (None, 7, 7, 256)            33024     ['re_lu_8[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 7, 7, 256)            590080    ['re_lu_9[0][0]']
#
#  batch_normalization_10 (Ba  (None, 7, 7, 256)            1024      ['conv2d_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_12 (Ba  (None, 7, 7, 256)            1024      ['conv2d_12[0][0]']
#  tchNormalization)
#
#  add_4 (Add)                 (None, 7, 7, 256)            0         ['batch_normalization_10[0][0]
#                                                                     ',
#                                                                      'batch_normalization_12[0][0]
#                                                                     ']
#
#  re_lu_10 (ReLU)             (None, 7, 7, 256)            0         ['add_4[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 7, 7, 256)            590080    ['re_lu_10[0][0]']
#
#  batch_normalization_13 (Ba  (None, 7, 7, 256)            1024      ['conv2d_13[0][0]']
#  tchNormalization)
#
#  re_lu_11 (ReLU)             (None, 7, 7, 256)            0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv2d_14 (Conv2D)          (None, 7, 7, 256)            590080    ['re_lu_11[0][0]']
#
#  batch_normalization_14 (Ba  (None, 7, 7, 256)            1024      ['conv2d_14[0][0]']
#  tchNormalization)
#
#  add_5 (Add)                 (None, 7, 7, 256)            0         ['re_lu_10[0][0]',
#                                                                      'batch_normalization_14[0][0]
#                                                                     ']
#
#  re_lu_12 (ReLU)             (None, 7, 7, 256)            0         ['add_5[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 4, 4, 512)            1180160   ['re_lu_12[0][0]']
#
#  batch_normalization_16 (Ba  (None, 4, 4, 512)            2048      ['conv2d_16[0][0]']
#  tchNormalization)
#
#  re_lu_13 (ReLU)             (None, 4, 4, 512)            0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, 4, 4, 512)            131584    ['re_lu_12[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 4, 4, 512)            2359808   ['re_lu_13[0][0]']
#
#  batch_normalization_15 (Ba  (None, 4, 4, 512)            2048      ['conv2d_15[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, 4, 4, 512)            2048      ['conv2d_17[0][0]']
#  tchNormalization)
#
#  add_6 (Add)                 (None, 4, 4, 512)            0         ['batch_normalization_15[0][0]
#                                                                     ',
#                                                                      'batch_normalization_17[0][0]
#                                                                     ']
#
#  re_lu_14 (ReLU)             (None, 4, 4, 512)            0         ['add_6[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 4, 4, 512)            2359808   ['re_lu_14[0][0]']
#
#  batch_normalization_18 (Ba  (None, 4, 4, 512)            2048      ['conv2d_18[0][0]']
#  tchNormalization)
#
#  re_lu_15 (ReLU)             (None, 4, 4, 512)            0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 4, 4, 512)            2359808   ['re_lu_15[0][0]']
#
#  batch_normalization_19 (Ba  (None, 4, 4, 512)            2048      ['conv2d_19[0][0]']
#  tchNormalization)
#
#  add_7 (Add)                 (None, 4, 4, 512)            0         ['re_lu_14[0][0]',
#                                                                      'batch_normalization_19[0][0]
#                                                                     ']
#
#  re_lu_16 (ReLU)             (None, 4, 4, 512)            0         ['add_7[0][0]']
#
#  global_average_pooling2d (  (None, 512)                  0         ['re_lu_16[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 345)                  176985    ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 11359065 (43.33 MB)
# Trainable params: 11349465 (43.29 MB)
# Non-trainable params: 9600 (37.50 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# Create a new model without the top layer

# %%
model = Model(inputs=model.input, outputs=model.get_layer('re_lu_16').output)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]          0         []
#
#  conv2d (Conv2D)             (None, 28, 28, 64)           640       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 28, 28, 64)           256       ['conv2d[0][0]']
#  Normalization)
#
#  re_lu (ReLU)                (None, 28, 28, 64)           0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 64)           36928     ['re_lu[0][0]']
#
#  batch_normalization_1 (Bat  (None, 28, 28, 64)           256       ['conv2d_1[0][0]']
#  chNormalization)
#
#  re_lu_1 (ReLU)              (None, 28, 28, 64)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 64)           36928     ['re_lu_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 28, 28, 64)           256       ['conv2d_2[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 28, 28, 64)           0         ['re_lu[0][0]',
#                                                                      'batch_normalization_2[0][0]'
#                                                                     ]
#
#  re_lu_2 (ReLU)              (None, 28, 28, 64)           0         ['add[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 64)           36928     ['re_lu_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 28, 28, 64)           256       ['conv2d_3[0][0]']
#  chNormalization)
#
#  re_lu_3 (ReLU)              (None, 28, 28, 64)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 28, 28, 64)           36928     ['re_lu_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 28, 28, 64)           256       ['conv2d_4[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 28, 28, 64)           0         ['re_lu_2[0][0]',
#                                                                      'batch_normalization_4[0][0]'
#                                                                     ]
#
#  re_lu_4 (ReLU)              (None, 28, 28, 64)           0         ['add_1[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 14, 14, 128)          73856     ['re_lu_4[0][0]']
#
#  batch_normalization_6 (Bat  (None, 14, 14, 128)          512       ['conv2d_6[0][0]']
#  chNormalization)
#
#  re_lu_5 (ReLU)              (None, 14, 14, 128)          0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 14, 14, 128)          8320      ['re_lu_4[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 14, 14, 128)          147584    ['re_lu_5[0][0]']
#
#  batch_normalization_5 (Bat  (None, 14, 14, 128)          512       ['conv2d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 14, 14, 128)          512       ['conv2d_7[0][0]']
#  chNormalization)
#
#  add_2 (Add)                 (None, 14, 14, 128)          0         ['batch_normalization_5[0][0]'
#                                                                     , 'batch_normalization_7[0][0]
#                                                                     ']
#
#  re_lu_6 (ReLU)              (None, 14, 14, 128)          0         ['add_2[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 14, 14, 128)          147584    ['re_lu_6[0][0]']
#
#  batch_normalization_8 (Bat  (None, 14, 14, 128)          512       ['conv2d_8[0][0]']
#  chNormalization)
#
#  re_lu_7 (ReLU)              (None, 14, 14, 128)          0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 14, 14, 128)          147584    ['re_lu_7[0][0]']
#
#  batch_normalization_9 (Bat  (None, 14, 14, 128)          512       ['conv2d_9[0][0]']
#  chNormalization)
#
#  add_3 (Add)                 (None, 14, 14, 128)          0         ['re_lu_6[0][0]',
#                                                                      'batch_normalization_9[0][0]'
#                                                                     ]
#
#  re_lu_8 (ReLU)              (None, 14, 14, 128)          0         ['add_3[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 7, 7, 256)            295168    ['re_lu_8[0][0]']
#
#  batch_normalization_11 (Ba  (None, 7, 7, 256)            1024      ['conv2d_11[0][0]']
#  tchNormalization)
#
#  re_lu_9 (ReLU)              (None, 7, 7, 256)            0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_10 (Conv2D)          (None, 7, 7, 256)            33024     ['re_lu_8[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 7, 7, 256)            590080    ['re_lu_9[0][0]']
#
#  batch_normalization_10 (Ba  (None, 7, 7, 256)            1024      ['conv2d_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_12 (Ba  (None, 7, 7, 256)            1024      ['conv2d_12[0][0]']
#  tchNormalization)
#
#  add_4 (Add)                 (None, 7, 7, 256)            0         ['batch_normalization_10[0][0]
#                                                                     ',
#                                                                      'batch_normalization_12[0][0]
#                                                                     ']
#
#  re_lu_10 (ReLU)             (None, 7, 7, 256)            0         ['add_4[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 7, 7, 256)            590080    ['re_lu_10[0][0]']
#
#  batch_normalization_13 (Ba  (None, 7, 7, 256)            1024      ['conv2d_13[0][0]']
#  tchNormalization)
#
#  re_lu_11 (ReLU)             (None, 7, 7, 256)            0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv2d_14 (Conv2D)          (None, 7, 7, 256)            590080    ['re_lu_11[0][0]']
#
#  batch_normalization_14 (Ba  (None, 7, 7, 256)            1024      ['conv2d_14[0][0]']
#  tchNormalization)
#
#  add_5 (Add)                 (None, 7, 7, 256)            0         ['re_lu_10[0][0]',
#                                                                      'batch_normalization_14[0][0]
#                                                                     ']
#
#  re_lu_12 (ReLU)             (None, 7, 7, 256)            0         ['add_5[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 4, 4, 512)            1180160   ['re_lu_12[0][0]']
#
#  batch_normalization_16 (Ba  (None, 4, 4, 512)            2048      ['conv2d_16[0][0]']
#  tchNormalization)
#
#  re_lu_13 (ReLU)             (None, 4, 4, 512)            0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, 4, 4, 512)            131584    ['re_lu_12[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 4, 4, 512)            2359808   ['re_lu_13[0][0]']
#
#  batch_normalization_15 (Ba  (None, 4, 4, 512)            2048      ['conv2d_15[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, 4, 4, 512)            2048      ['conv2d_17[0][0]']
#  tchNormalization)
#
#  add_6 (Add)                 (None, 4, 4, 512)            0         ['batch_normalization_15[0][0]
#                                                                     ',
#                                                                      'batch_normalization_17[0][0]
#                                                                     ']
#
#  re_lu_14 (ReLU)             (None, 4, 4, 512)            0         ['add_6[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 4, 4, 512)            2359808   ['re_lu_14[0][0]']
#
#  batch_normalization_18 (Ba  (None, 4, 4, 512)            2048      ['conv2d_18[0][0]']
#  tchNormalization)
#
#  re_lu_15 (ReLU)             (None, 4, 4, 512)            0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 4, 4, 512)            2359808   ['re_lu_15[0][0]']
#
#  batch_normalization_19 (Ba  (None, 4, 4, 512)            2048      ['conv2d_19[0][0]']
#  tchNormalization)
#
#  add_7 (Add)                 (None, 4, 4, 512)            0         ['re_lu_14[0][0]',
#                                                                      'batch_normalization_19[0][0]
#                                                                     ']
#
#  re_lu_16 (ReLU)             (None, 4, 4, 512)            0         ['add_7[0][0]']
#
# ==================================================================================================
# Total params: 11182080 (42.66 MB)
# Trainable params: 11172480 (42.62 MB)
# Non-trainable params: 9600 (37.50 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# ## **Cargar dataset**

# %%
# Get image paths and labels
filenames = glob.glob('./AutismSketchClassifier/data/*/*.png')
labels = [os.path.basename(os.path.dirname(filename)) for filename in filenames]
filenames
# Out:
# ['./AutismSketchClassifier/data/Ojos distanciados/eedibujo (10).png',
#  './AutismSketchClassifier/data/Ojos distanciados/eedibujo (31).png',
#  './AutismSketchClassifier/data/Ojos distanciados/eeDrawing (67).png',
#  './AutismSketchClassifier/data/Ojos distanciados/eeDrawing (10).png',
#  './AutismSketchClassifier/data/Ojos distanciados/eetmpzercsekj.png',
#  './AutismSketchClassifier/data/Ojos distanciados/tmp94uqapi7.png',
#  './AutismSketchClassifier/data/Ojos distanciados/eeDrawing (60).png',
#  './AutismSketchClassifier/data/Ojos distanciados/eeDrawing (40).png',
#  './AutismSketchClassifier/data/Ojos distanciados/eedibujo (17).png',
#  './AutismSketchClassifier/data/Ojos distanciados/eeDrawing (94).png',
#  './AutismSketchClassifier/data/Ojos distanciados/eeDrawing (9).png',
#  './AutismSketchClassifier/data/Ojos distanciados/eeDrawing (15).png',
#  './AutismSketchClassifier/data/Ojos distanciados/tmp6f9izlz1.png',
#  './AutismSketchClassifier/data/Ojos distanciados/eetmphkvtqtnx.png',
#  './AutismSketchClassifier/data/Ojos distanciados/eeDrawing (9) copy.png',
#  './AutismSketchClassifier/data/Ojos distanciados/eeDrawing (80).png',
#  './AutismSketchClassifier/data/Ojos distanciados/tmpkljbsi52.png',
#  './AutismSketchClassifier/data/Ojos distanciados/eeDrawing (34).png',
#  './AutismSketchClassifier/data/Ojos distanciados/eeDrawing (22).png',
#  './AutismSketchClassifier/data/Ojos distanciados/eeDrawing (100).png',
#  './AutismSketchClassifier/data/Ojos distanciados/eeDrawing (29).png',
#  './AutismSketchClassifier/data/Ojos distanciados/eeDrawing (3).png',
#  './AutismSketchClassifier/data/Ojos distanciados/eeDrawing (87).png',
#  './AutismSketchClassifier/data/Ojos distanciados/eedibujo (24).png',
#  './AutismSketchClassifier/data/Ojos distanciados/eeDrawing (3) copy.png',
#  './AutismSketchClassifier/data/Ojos distanciados/eeDrawing (73).png',
#  './AutismSketchClassifier/data/Ojos distanciados/eeDrawing (2).png',
#  './AutismSketchClassifier/data/Ojos distanciados/tmpuymuylqc.png',
#  './AutismSketchClassifier/data/Ojos distanciados/tmpf9z5ct7f.png',
#  './AutismSketchClassifier/data/Ojos distanciados/tmphoypmxxy.png',
#  './AutismSketchClassifier/data/Ojos distanciados/eeDrawing (53).png',
#  './AutismSketchClassifier/data/Sin cejas/rrDrawing (66).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(48).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(126).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(130).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(25).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(72).png',
#  './AutismSketchClassifier/data/Sin cejas/rrdibujo (9).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(64).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(33).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(44).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo (23).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(13).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(7).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T212547.536.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(52).png',
#  './AutismSketchClassifier/data/Sin cejas/rrDrawing (93).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214536.825.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(29).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T194529.806.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(91).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(110).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214657.656.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T194106.248.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(106).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(87).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(68).png',
#  './AutismSketchClassifier/data/Sin cejas/rrDrawing (46).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo (59).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214313.273.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(107).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(86).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(69).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(90).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(111).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo (9).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(28).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(53).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T194945.559.png',
#  './AutismSketchClassifier/data/Sin cejas/tmp8u_bob18.png',
#  './AutismSketchClassifier/data/Sin cejas/rrdibujo (16).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(12).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(6).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214738.029.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(45).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(32).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(65).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(73).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(24).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(131).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo (80).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(49).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(127).png',
#  './AutismSketchClassifier/data/Sin cejas/rrDrawing (8) copy.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(42).png',
#  './AutismSketchClassifier/data/Sin cejas/rrDrawing (2) copy.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(1).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(15).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214130.919.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(54).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(141).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(116).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(97).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(78).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(81).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(100).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214303.968.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214350.453.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(39).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214330.385.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(120).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(19).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo (87).png',
#  './AutismSketchClassifier/data/Sin cejas/rrDrawing (21).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214627.490.png',
#  './AutismSketchClassifier/data/Sin cejas/rrDrawing (99).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(58).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(136).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo (44).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo (2).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(23).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(74).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(62).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214147.527.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo (52).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(35).png',
#  './AutismSketchClassifier/data/Sin cejas/rrdibujo (30).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(34).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(63).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(75).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(22).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214153.701.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(59).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214339.802.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(137).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo (101).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(18).png',
#  './AutismSketchClassifier/data/Sin cejas/tmpyuos33w3.png',
#  './AutismSketchClassifier/data/Sin cejas/tmpzttmp4pz.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(121).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214707.498.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(38).png',
#  './AutismSketchClassifier/data/Sin cejas/rrDibujo (2).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(80).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(101).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(117).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(96).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(79).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(140).png',
#  './AutismSketchClassifier/data/Sin cejas/rrDrawing (1).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(55).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214521.035.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo (73).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(14).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214527.299.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(43).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214651.243.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(102).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(83).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(95).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(114).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214503.755.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214142.246.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(138).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(56).png',
#  './AutismSketchClassifier/data/Sin cejas/rrDrawing (2).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214125.920.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo (66).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T174038.301.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(17).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(3).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214822.476.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(40).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(37).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214733.021.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(60).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(76).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(118).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(99).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(21).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214115.568.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(134).png',
#  './AutismSketchClassifier/data/Sin cejas/tmpq4g36ebg.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214438.847.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(122).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(123).png',
#  './AutismSketchClassifier/data/Sin cejas/tmp_opnwh8k.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(135).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(20).png',
#  './AutismSketchClassifier/data/Sin cejas/rrDrawing (59).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(77).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(119).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(98).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(61).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(36).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214335.232.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(41).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(16).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(2).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T212555.107.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(139).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214103.503.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(57).png',
#  './AutismSketchClassifier/data/Sin cejas/rrDrawing (79).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo (30).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(142).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(94).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(115).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(103).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(82).png',
#  './AutismSketchClassifier/data/Sin cejas/rrDrawing (14).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214718.060.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(31).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(66).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214356.482.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(108).png',
#  './AutismSketchClassifier/data/Sin cejas/tmpyw23zcgy.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(89).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(70).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(27).png',
#  './AutismSketchClassifier/data/Sin cejas/rrdibujo (23).png',
#  './AutismSketchClassifier/data/Sin cejas/rrtmpskgjao6x.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214205.064.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(132).png',
#  './AutismSketchClassifier/data/Sin cejas/rrDrawing (8).png',
#  './AutismSketchClassifier/data/Sin cejas/rrDrawing (72).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214344.784.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(9).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(124).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214250.276.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214758.519.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(85).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(104).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(112).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(93).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo (37).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(50).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214136.115.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(5).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(11).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(128).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(46).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(129).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214325.522.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(47).png',
#  './AutismSketchClassifier/data/Sin cejas/rrDrawing (86).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214514.639.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(4).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(10).png',
#  './AutismSketchClassifier/data/Sin cejas/rrDrawing (28).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(51).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(113).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(92).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(84).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(105).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214723.085.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214532.360.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(125).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214449.923.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo (94).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(8).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214712.600.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo - 2024-06-02T214121.152.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(133).png',
#  './AutismSketchClassifier/data/Sin cejas/rrDrawing (9).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(26).png',
#  './AutismSketchClassifier/data/Sin cejas/rrtmpkejpd91c.png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo (16).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(71).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(67).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(109).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(88).png',
#  './AutismSketchClassifier/data/Sin cejas/dibujo(30).png',
#  './AutismSketchClassifier/data/Dibujos Presquemáticos/wwdibujo (25).png',
#  './AutismSketchClassifier/data/Dibujos Presquemáticos/wwDrawing (54).png',
#  './AutismSketchClassifier/data/Dibujos Presquemáticos/wwDrawing (81).png',
#  './AutismSketchClassifier/data/Dibujos Presquemáticos/wwDrawing (23).png',
#  './AutismSketchClassifier/data/Dibujos Presquemáticos/wwDrawing (74).png',
#  './AutismSketchClassifier/data/Dibujos Presquemáticos/wwDrawing (35).png',
#  './AutismSketchClassifier/data/Dibujos Presquemáticos/wwDibujo (12).png',
#  './AutismSketchClassifier/data/Dibujos Presquemáticos/wwDrawing (3).png',
#  './AutismSketchClassifier/data/Dibujos Presquemáticos/wwtmpk9bb6zst.png',
#  './AutismSketchClassifier/data/Dibujos Presquemáticos/wwdibujo.png',
#  './AutismSketchClassifier/data/Dibujos Presquemáticos/wwdibujo (32).png',
#  './AutismSketchClassifier/data/Dibujos Presquemáticos/wwDrawing (48).png',
#  './AutismSketchClassifier/data/Dibujos Presquemáticos/wwDrawing (4) copy.png',
#  './AutismSketchClassifier/data/Dibujos Presquemáticos/wwDrawing (4).png',
#  './AutismSketchClassifier/data/Dibujos Presquemáticos/tmp0z1cjmki.png',
#  './AutismSketchClassifier/data/Dibujos Presquemáticos/wwdibujo (18).png',
#  './AutismSketchClassifier/data/Dibujos Presquemáticos/tmp0zoecshp.png',
#  './AutismSketchClassifier/data/Dibujos Presquemáticos/tmpgkancg0b.png',
#  './AutismSketchClassifier/data/Dibujos Presquemáticos/wwDrawing (11).png',
#  './AutismSketchClassifier/data/Dibujos Presquemáticos/wwDrawing (10) copy.png',
#  './AutismSketchClassifier/data/Dibujos Presquemáticos/wwDrawing (10).png',
#  './AutismSketchClassifier/data/Dibujos Presquemáticos/wwDibujo (4).png',
#  './AutismSketchClassifier/data/Dibujos Presquemáticos/tmp_l7ujf59.png',
#  './AutismSketchClassifier/data/Dibujos Presquemáticos/wwDrawing (88).png',
#  './AutismSketchClassifier/data/Dibujos Presquemáticos/tmpiwggwbmf.png',
#  './AutismSketchClassifier/data/Dibujos Presquemáticos/wwDrawing (30).png',
#  './AutismSketchClassifier/data/Dibujos Presquemáticos/tmprpc2i5gz.png',
#  './AutismSketchClassifier/data/Dibujos Presquemáticos/wwDibujo (3).png',
#  './AutismSketchClassifier/data/Dibujos Presquemáticos/wwDrawing (61).png',
#  './AutismSketchClassifier/data/Dibujos Presquemáticos/wwDrawing (41).png',
#  './AutismSketchClassifier/data/Dibujos Presquemáticos/wwDrawing (16).png',
#  './AutismSketchClassifier/data/Con cuello/qqDrawing (82).png',
#  './AutismSketchClassifier/data/Con cuello/qqDrawing (5).png',
#  './AutismSketchClassifier/data/Con cuello/tmp8e84x0w6.png',
#  './AutismSketchClassifier/data/Con cuello/tmpxpw2fsjn.png',
#  './AutismSketchClassifier/data/Con cuello/qqDrawing (36).png',
#  './AutismSketchClassifier/data/Con cuello/tmpr61sk6oo.png',
#  './AutismSketchClassifier/data/Con cuello/qqtmp89f3ldan.png',
#  './AutismSketchClassifier/data/Con cuello/qqdibujo (19).png',
#  './AutismSketchClassifier/data/Con cuello/qqDrawing (17).png',
#  './AutismSketchClassifier/data/Con cuello/qqDrawing (4).png',
#  './AutismSketchClassifier/data/Con cuello/qqDrawing (95).png',
#  './AutismSketchClassifier/data/Con cuello/tmppuhgsxp0.png',
#  './AutismSketchClassifier/data/Con cuello/tmpsdontavx.png',
#  './AutismSketchClassifier/data/Con cuello/qqDrawing (11) copy.png',
#  './AutismSketchClassifier/data/Con cuello/qqDrawing (11).png',
#  './AutismSketchClassifier/data/Con cuello/qqdibujo (5).png',
#  './AutismSketchClassifier/data/Con cuello/qqdibujo (33).png',
#  './AutismSketchClassifier/data/Con cuello/qqDrawing (31).png',
#  './AutismSketchClassifier/data/Con cuello/qqDrawing (89).png',
#  './AutismSketchClassifier/data/Con cuello/qqDrawing (49).png',
#  './AutismSketchClassifier/data/Con cuello/qqdibujo (26).png',
#  './AutismSketchClassifier/data/Con cuello/qqDrawing (24).png',
#  './AutismSketchClassifier/data/Con cuello/qqDrawing (12).png',
#  './AutismSketchClassifier/data/Con cuello/qqDrawing (68).png',
#  './AutismSketchClassifier/data/Con cuello/qqdibujo (11).png',
#  './AutismSketchClassifier/data/Con cuello/qqDrawing (55).png',
#  './AutismSketchClassifier/data/Con cuello/qqDrawing (5) copy.png',
#  './AutismSketchClassifier/data/Con cuello/qqDrawing (75).png',
#  './AutismSketchClassifier/data/Con cuello/qqDrawing (62).png',
#  './AutismSketchClassifier/data/Con cuello/tmpxongwolu.png',
#  './AutismSketchClassifier/data/Con cuello/qqDrawing (42).png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T220544.752.png',
#  './AutismSketchClassifier/data/Shaky lines/ssdibujo (27).png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T215623.866.png',
#  './AutismSketchClassifier/data/Shaky lines/tmpqtr6uvtb.png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T215207.932.png',
#  './AutismSketchClassifier/data/Shaky lines/ssDrawing (12) copy.png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T220115.647.png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T215540.662.png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T215823.062.png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo (34).png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo (63).png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T215945.752.png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T220107.753.png',
#  './AutismSketchClassifier/data/Shaky lines/ssDrawing (50).png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T220242.979.png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T215411.802.png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T220210.321.png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T220202.026.png',
#  './AutismSketchClassifier/data/Shaky lines/ssdibujo (6).png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T215332.563.png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T194756.153.png',
#  './AutismSketchClassifier/data/Shaky lines/ssDrawing (6).png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo (48).png',
#  './AutismSketchClassifier/data/Shaky lines/tmpi46ot2r6.png',
#  './AutismSketchClassifier/data/Shaky lines/tmp0b8tjy6y.png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T220126.204.png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo (91).png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T220510.644.png',
#  './AutismSketchClassifier/data/Shaky lines/ssDibujo (21).png',
#  './AutismSketchClassifier/data/Shaky lines/ssDibujo (1).png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo (13).png',
#  './AutismSketchClassifier/data/Shaky lines/ssDrawing (56).png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T173452.316.png',
#  './AutismSketchClassifier/data/Shaky lines/tmpjyopbwf7.png',
#  './AutismSketchClassifier/data/Shaky lines/ssDrawing (83).png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T215616.860.png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T215630.337.png',
#  './AutismSketchClassifier/data/Shaky lines/sstmpti8oilms.png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T215313.055.png',
#  './AutismSketchClassifier/data/Shaky lines/ssDrawing (37).png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T215358.789.png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T194352.318.png',
#  './AutismSketchClassifier/data/Shaky lines/ssDrawing (76).png',
#  './AutismSketchClassifier/data/Shaky lines/ssDrawing (18).png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T215843.137.png',
#  './AutismSketchClassifier/data/Shaky lines/ssDrawing (63).png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo (70).png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo (27).png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T215742.359.png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T215608.594.png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T174418.248.png',
#  './AutismSketchClassifier/data/Shaky lines/ssDrawing (43).png',
#  './AutismSketchClassifier/data/Shaky lines/ssDrawing (96).png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T215456.992.png',
#  './AutismSketchClassifier/data/Shaky lines/ssdibujo (34).png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T220449.965.png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo (84).png',
#  './AutismSketchClassifier/data/Shaky lines/tmp2gjqy7y5.png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T215305.392.png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T195332.899.png',
#  './AutismSketchClassifier/data/Shaky lines/ssDrawing (5).png',
#  './AutismSketchClassifier/data/Shaky lines/ssDrawing (6) copy.png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo (56).png',
#  './AutismSketchClassifier/data/Shaky lines/tmpjz8eqvme.png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T215342.579.png',
#  './AutismSketchClassifier/data/Shaky lines/ssDrawing (12).png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo (6).png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T215559.336.png',
#  './AutismSketchClassifier/data/Shaky lines/ssDrawing (69).png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T215321.958.png',
#  './AutismSketchClassifier/data/Shaky lines/ssDrawing (90).png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T215935.672.png',
#  './AutismSketchClassifier/data/Shaky lines/ssdibujo (13).png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T220218.102.png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T215252.445.png',
#  './AutismSketchClassifier/data/Shaky lines/ssDrawing (32).png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T215805.858.png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T215953.874.png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T215531.810.png',
#  './AutismSketchClassifier/data/Shaky lines/ssDrawing (25).png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo (20).png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo (98).png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo (77).png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T215853.152.png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T215832.866.png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T215448.586.png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T215549.641.png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T220441.095.png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo (41).png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T220459.737.png',
#  './AutismSketchClassifier/data/Shaky lines/dibujo - 2024-06-02T215710.218.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(48).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T195439.758.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(126).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo (78).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(130).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo (42).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(25).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(72).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T200459.478.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T200244.925.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(64).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(33).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T200314.421.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(44).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(13).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(7).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T200111.684.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T195738.226.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(52).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo (35).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(29).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(91).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(110).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(106).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(87).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(68).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(107).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(86).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(69).png',
#  './AutismSketchClassifier/data/Con ojos negros/ttDrawing (91).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(90).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(111).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(28).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(53).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T195814.968.png',
#  './AutismSketchClassifier/data/Con ojos negros/ttdibujo (7).png',
#  './AutismSketchClassifier/data/Con ojos negros/ttDrawing (13).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(12).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(6).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(45).png',
#  './AutismSketchClassifier/data/Con ojos negros/ttDrawing (44).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T195833.827.png',
#  './AutismSketchClassifier/data/Con ojos negros/ttDrawing (33).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(32).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T195928.983.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(65).png',
#  './AutismSketchClassifier/data/Con ojos negros/ttDrawing (64).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(73).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo (14).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T193750.894.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(24).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(131).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T195951.270.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T195944.043.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(49).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(127).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(42).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(1).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(15).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T200320.550.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo (64).png',
#  './AutismSketchClassifier/data/Con ojos negros/ttdibujo (20).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(54).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(141).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T200307.350.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(116).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(97).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(78).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(81).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(100).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(39).png',
#  './AutismSketchClassifier/data/Con ojos negros/ttDrawing (38).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(120).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(19).png',
#  './AutismSketchClassifier/data/Con ojos negros/tmpkuq0snqp.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(58).png',
#  './AutismSketchClassifier/data/Con ojos negros/tmpqp2iqx4r.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(136).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(23).png',
#  './AutismSketchClassifier/data/Con ojos negros/ttDrawing (7).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(74).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(62).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(35).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(34).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(63).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T195936.195.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(75).png',
#  './AutismSketchClassifier/data/Con ojos negros/ttDrawing (6).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T200536.299.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(22).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T194835.475.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T200529.803.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(59).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(137).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T200342.755.png',
#  './AutismSketchClassifier/data/Con ojos negros/tttmpoz3lwgjx.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(18).png',
#  './AutismSketchClassifier/data/Con ojos negros/ttDrawing (19).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(121).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo (28).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(38).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(80).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(101).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T200336.302.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(117).png',
#  './AutismSketchClassifier/data/Con ojos negros/ttDrawing (97).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(96).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(79).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T200302.007.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo (49).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(140).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(55).png',
#  './AutismSketchClassifier/data/Con ojos negros/ttDibujo (1).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(14).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(43).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T200516.425.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(102).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(83).png',
#  './AutismSketchClassifier/data/Con ojos negros/tttmpqvdmicl9.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(95).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(114).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(138).png',
#  './AutismSketchClassifier/data/Con ojos negros/ttDrawing (57).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(56).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(17).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(3).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T200510.444.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(40).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(37).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo (50).png',
#  './AutismSketchClassifier/data/Con ojos negros/ttdibujo (14).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(60).png',
#  './AutismSketchClassifier/data/Con ojos negros/tmpujmf4zyv.png',
#  './AutismSketchClassifier/data/Con ojos negros/ttDrawing (77).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(76).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(118).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(99).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T200102.665.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(21).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T200555.657.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T195820.828.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(134).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo (85).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(122).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T200545.732.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T195511.272.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T200200.396.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(123).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo (92).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(135).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T200504.649.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(20).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(77).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T195842.597.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(119).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(98).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(61).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T200522.058.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(36).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T173523.255.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(41).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(16).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(2).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T195958.581.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo (71).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(139).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(57).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(142).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(94).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(115).png',
#  './AutismSketchClassifier/data/Con ojos negros/tmpdtqvl9ni.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(103).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(82).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T195826.788.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(31).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(66).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(108).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(89).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(70).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(27).png',
#  './AutismSketchClassifier/data/Con ojos negros/ttDrawing (26).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(132).png',
#  './AutismSketchClassifier/data/Con ojos negros/ttdibujo (28).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(9).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T200118.539.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(124).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T200605.768.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T200050.998.png',
#  './AutismSketchClassifier/data/Con ojos negros/ttDrawing.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(85).png',
#  './AutismSketchClassifier/data/Con ojos negros/ttDrawing (84).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(104).png',
#  './AutismSketchClassifier/data/Con ojos negros/tmpt70gzv19.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(112).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(93).png',
#  './AutismSketchClassifier/data/Con ojos negros/ttDrawing (51).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(50).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo (99).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(5).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(11).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo (21).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(128).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(46).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(129).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(47).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T200328.670.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(4).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(10).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T200250.300.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(51).png',
#  './AutismSketchClassifier/data/Con ojos negros/ttDibujo (1) copy.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(113).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(92).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(84).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(105).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(125).png',
#  './AutismSketchClassifier/data/Con ojos negros/ttDrawing copy.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(8).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(133).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo (7).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(26).png',
#  './AutismSketchClassifier/data/Con ojos negros/ttDrawing (70).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T195532.750.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(71).png',
#  './AutismSketchClassifier/data/Con ojos negros/tmp9y9w8mao.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T194420.276.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T195459.042.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(67).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(109).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(88).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo (57).png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo - 2024-06-02T200256.192.png',
#  './AutismSketchClassifier/data/Con ojos negros/dibujo(30).png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo (15).png',
#  './AutismSketchClassifier/data/Sonrisa grande/ggDrawing (8).png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T203046.058.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T211206.433.png',
#  './AutismSketchClassifier/data/Sonrisa grande/tmpcaw_8fx1.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo (8).png',
#  './AutismSketchClassifier/data/Sonrisa grande/ggdibujo (15).png',
#  './AutismSketchClassifier/data/Sonrisa grande/tmp4uyg5cwu.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo (58).png',
#  './AutismSketchClassifier/data/Sonrisa grande/ggDrawing (98).png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo (22).png',
#  './AutismSketchClassifier/data/Sonrisa grande/ggDrawing (20).png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T211127.047.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T212118.458.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo (43).png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T212050.768.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo (79).png',
#  './AutismSketchClassifier/data/Sonrisa grande/ggdibujo (22).png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T211710.522.png',
#  './AutismSketchClassifier/data/Sonrisa grande/ggDrawing (27).png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T193849.523.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo (72).png',
#  './AutismSketchClassifier/data/Sonrisa grande/ggdibujo (29).png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T212125.922.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T194506.442.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo (29).png',
#  './AutismSketchClassifier/data/Sonrisa grande/tmp0hfxjq_e.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo (100).png',
#  './AutismSketchClassifier/data/Sonrisa grande/ggDrawing (85).png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T211225.477.png',
#  './AutismSketchClassifier/data/Sonrisa grande/tmpz8z8o5tu.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T203149.838.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T211737.141.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T211619.654.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo (86).png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T203524.026.png',
#  './AutismSketchClassifier/data/Sonrisa grande/ggDrawing (92).png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T210212.803.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T203030.156.png',
#  './AutismSketchClassifier/data/Sonrisa grande/tmp5ejjc912.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo (65).png',
#  './AutismSketchClassifier/data/Sonrisa grande/ggDrawing (71).png',
#  './AutismSketchClassifier/data/Sonrisa grande/tmpzmc2wgzu.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T211626.920.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T211720.331.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T202919.323.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T212215.755.png',
#  './AutismSketchClassifier/data/Sonrisa grande/ggDrawing (52).png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T211139.901.png',
#  './AutismSketchClassifier/data/Sonrisa grande/ggtmpk62hz6x7.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T202955.696.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T173825.834.png',
#  './AutismSketchClassifier/data/Sonrisa grande/ggDrawing (13).png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo (93).png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T212043.374.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T203504.247.png',
#  './AutismSketchClassifier/data/Sonrisa grande/ggDibujo (2).png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T212133.160.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo (1).png',
#  './AutismSketchClassifier/data/Sonrisa grande/ggDrawing (45).png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T203018.257.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T211634.639.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo (51).png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T211158.185.png',
#  './AutismSketchClassifier/data/Sonrisa grande/ggDrawing (65).png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T211237.025.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T212107.070.png',
#  './AutismSketchClassifier/data/Sonrisa grande/ggDrawing (1).png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T212256.777.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T203546.507.png',
#  './AutismSketchClassifier/data/Sonrisa grande/ggDrawing (39).png',
#  './AutismSketchClassifier/data/Sonrisa grande/ggDrawing (78).png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T211702.159.png',
#  './AutismSketchClassifier/data/Sonrisa grande/ggDrawing (58).png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T211644.565.png',
#  './AutismSketchClassifier/data/Sonrisa grande/ggDrawing (1) copy.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T202929.305.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T211215.895.png',
#  './AutismSketchClassifier/data/Sonrisa grande/tmpzpzmklfw.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T194920.529.png',
#  './AutismSketchClassifier/data/Sonrisa grande/ggdibujo (8).png',
#  './AutismSketchClassifier/data/Sonrisa grande/ggDrawing.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo (36).png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T211729.236.png',
#  './AutismSketchClassifier/data/Sonrisa grande/ggDrawing (7).png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T212140.852.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T211653.084.png',
#  './AutismSketchClassifier/data/Sonrisa grande/ggtmp24o9spmy.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T211118.311.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T212148.498.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T202941.407.png',
#  './AutismSketchClassifier/data/Sonrisa grande/ggDrawing (7) copy.png',
#  './AutismSketchClassifier/data/Sonrisa grande/dibujo - 2024-06-02T211148.508.png']

# %% [markdown]
# Mostramos las imagenes del dataset

# %%
fig = plt.figure(figsize=(8, 9))
num_images = 40 #len(filenames)
images_per_row = 8
num_rows = (num_images // images_per_row) + int(num_images % images_per_row != 0)

for i in range(num_images):
    ax = fig.add_subplot(num_rows, images_per_row, i + 1)
    ax.imshow(imread(filenames[i]))
    ax.axis('off')
    ax.set_title(f"Image {i + 1}")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Obtenemos un vector de representación por cada imagen

# %% [markdown]
# Preprocesamos y obtenemos un vector de representación para cada una de las imágenes del dataset

# %%
def remove_transparency(im, bg_colour=(255, 255, 255)):
    # Only process if image has transparency
    if im.mode in ('RGBA', 'LA') or (im.mode == 'P' and 'transparency' in im.info):

        # Need to convert to RGBA if LA format due to a bug in PIL
        alpha = im.convert('RGBA').split()[-1]

        # Create a new background image of our matt color.
        # Must be RGBA because paste requires both images have the same format

        bg = PILImage.new("RGBA", im.size, bg_colour + (255,))
        bg.paste(im, mask=alpha)
        return bg

    else:
        return im

# %%
def extract_features_and_preprocessed_images(filenames):
    target_size=(28, 28)
    features = []
    preprocessed_images = []
    for filename in filenames:
        img = PILImage.open(filename)
        img = remove_transparency(img)
        img_resized = img.resize(target_size)
        img_gray = img_resized.convert('L')
        preprocessed_images.append(img_gray)
        x = image.img_to_array(img_gray)
        x = np.expand_dims(x, axis=0)
        x = x / 255.0
        features.append(model.predict(x).ravel())
    return np.array(features), preprocessed_images

# %%
# Split the data into training and test sets
filenames_train, filenames_test, labels_train, labels_test = train_test_split(filenames, labels, test_size=0.2, stratify=labels, random_state=42)

# Extract features and preprocessed images
features_train, preprocessed_images_train = extract_features_and_preprocessed_images(filenames_train)
features_test, preprocessed_images_test = extract_features_and_preprocessed_images(filenames_test)

labels_train = np.array(labels_train)
labels_test = np.array(labels_test)

print(f"Training features shape: {features_train.shape}")
print(f"Test features shape: {features_test.shape}")
# Out:
# 1/1 [==============================] - 1s 611ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 252ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# Training features shape: (595, 8192)
# Test features shape: (149, 8192)

# %% [markdown]
# Visualizamos

# %%
# Visualization
def visualize_image_and_features(img_gray, feature_vector):
    # Create subplots
    fig, axes = plt.subplots(1, 2, figsize=(12, 6))

    # Plot the image on the first subplot
    axes[0].imshow(img_gray, cmap="gray")
    axes[0].set_title("Image 28x28")
    axes[0].axis("off")

    # Plot the feature vector on the second subplot
    axes[1].plot(feature_vector)
    axes[1].set_title("Feature Vector")
    axes[1].set_xlabel("Index")
    axes[1].set_ylabel("Feature Value")

    plt.tight_layout()
    plt.show()

# Visualize one of the images and its feature vector
index_to_visualize = 13  # Change this index to visualize different images
visualize_image_and_features(preprocessed_images_train[index_to_visualize], features_train[index_to_visualize])

# %% [markdown]
# ## **KNN encontramos imágenes más similares**

# %%
# tomar la distancia del coseno:
def distancia_cos(im1, im2):
  return 1 - np.dot(im1, im2) / (np.linalg.norm(im1) * np.linalg.norm(im2))

# %%
def k_vecinos_más_cercanos(vectores_train, vectores_test, index, k):
    vecinos = []
    im1 = vectores_test[index]  # vector of the test image we are referencing
    for i, im2 in enumerate(vectores_train):
        D = distancia_cos(im1, im2)
        vecinos.append([i, D])  # store the index of the training image and its distance

    vecinos.sort(key=lambda x: x[1])
    return [x[0] for x in vecinos[:k]]  # return the indices of the k closest neighbors

# %%
# Display the query image and its nearest neighbors
idx = 1  # index of the test image we want to use as a query
k = 3  # number of neighbors to retrieve

print("Query Image")
query_img = PILImage.open(filenames_test[idx])
plt.imshow(query_img, cmap='gray')
plt.show()

# Get indices of k nearest neighbors from the training set
idxs = k_vecinos_más_cercanos(features_train, features_test, idx, k)

print("Retrieved Images (Total Images: {} images)".format(k))
# Out:
# Query Image
# Retrieved Images (Total Images: 3 images)

# %%
fig = plt.figure(figsize=(25, 9))

for i in range(k):
    ax = fig.add_subplot(1, k, i + 1) 
    img = PILImage.open(filenames_train[idxs[i]])
    ax.imshow(img, cmap='gray')
    ax.axis('off')  
    ax.set_title(f"Image {i + 1}") 

plt.tight_layout()  # Adjust subplots to fit into figure area.
plt.show()

# %% [markdown]
# ## **Clasificamos imágenes en base al KNN**

# %%
# Classify a single image from the test set
def classify_image(feature, features_train, labels_train, k=3):
    # Find k nearest neighbors in the training set
    neighbors_indices = k_vecinos_más_cercanos(features_train, [feature], 0, k)

    # Get the labels of the first k nearest neighbors
    neighbors_labels = [labels_train[i] for i in neighbors_indices]

    # Determine the majority label
    label_counter = Counter(neighbors_labels)
    majority_label = label_counter.most_common(1)[0][0]

    return majority_label

# %%
# Classify all images in the test set
predicted_labels = []
for feature_test in features_test:
    predicted_label = classify_image(feature_test, features_train, labels_train, k=10)
    predicted_labels.append(predicted_label)

# Convert to numpy array for easier comparison if needed
predicted_labels = np.array(predicted_labels)

# Output predicted labels
predicted_labels
# Out:
# array(['Sin cejas', 'Con ojos negros', 'Con cuello', 'Sin cejas',
#        'Sin cejas', 'Sin cejas', 'Con ojos negros', 'Sin cejas',
#        'Sin cejas', 'Ojos distanciados', 'Con cuello', 'Sin cejas',
#        'Sonrisa grande', 'Sin cejas', 'Shaky lines', 'Sin cejas',
#        'Con ojos negros', 'Con ojos negros', 'Sin cejas',
#        'Con ojos negros', 'Sonrisa grande', 'Con ojos negros',
#        'Sin cejas', 'Con ojos negros', 'Con cuello', 'Sin cejas',
#        'Sin cejas', 'Shaky lines', 'Sin cejas', 'Sin cejas',
#        'Ojos distanciados', 'Sin cejas', 'Sin cejas', 'Con ojos negros',
#        'Dibujos Presquemáticos', 'Con cuello', 'Con ojos negros',
#        'Ojos distanciados', 'Sonrisa grande', 'Sin cejas',
#        'Con ojos negros', 'Sin cejas', 'Con ojos negros', 'Sin cejas',
#        'Con ojos negros', 'Sonrisa grande', 'Shaky lines', 'Sin cejas',
#        'Con ojos negros', 'Sin cejas', 'Sonrisa grande', 'Sin cejas',
#        'Sin cejas', 'Con ojos negros', 'Con ojos negros',
#        'Con ojos negros', 'Con ojos negros', 'Sonrisa grande',
#        'Con ojos negros', 'Shaky lines', 'Con ojos negros', 'Sin cejas',
#        'Con ojos negros', 'Sonrisa grande', 'Con ojos negros',
#        'Shaky lines', 'Con ojos negros', 'Sin cejas', 'Shaky lines',
#        'Con ojos negros', 'Sin cejas', 'Shaky lines', 'Con ojos negros',
#        'Con ojos negros', 'Con ojos negros', 'Sin cejas', 'Shaky lines',
#        'Sonrisa grande', 'Sin cejas', 'Con ojos negros', 'Sin cejas',
#        'Shaky lines', 'Sin cejas', 'Shaky lines', 'Sin cejas',
#        'Sin cejas', 'Sin cejas', 'Sonrisa grande', 'Con ojos negros',
#        'Con ojos negros', 'Shaky lines', 'Sin cejas', 'Shaky lines',
#        'Ojos distanciados', 'Sin cejas', 'Con ojos negros',
#        'Con ojos negros', 'Dibujos Presquemáticos', 'Shaky lines',
#        'Sin cejas', 'Sin cejas', 'Con ojos negros',
#        'Dibujos Presquemáticos', 'Sin cejas', 'Sin cejas',
#        'Con ojos negros', 'Con ojos negros', 'Sonrisa grande',
#        'Sin cejas', 'Sin cejas', 'Sonrisa grande', 'Sin cejas',
#        'Sin cejas', 'Sin cejas', 'Sin cejas', 'Con cuello',
#        'Con ojos negros', 'Sonrisa grande', 'Con ojos negros',
#        'Con ojos negros', 'Sin cejas', 'Ojos distanciados',
#        'Ojos distanciados', 'Con ojos negros', 'Con cuello',
#        'Con ojos negros', 'Sonrisa grande', 'Sin cejas', 'Sin cejas',
#        'Con ojos negros', 'Shaky lines', 'Sonrisa grande',
#        'Con ojos negros', 'Dibujos Presquemáticos', 'Shaky lines',
#        'Sin cejas', 'Dibujos Presquemáticos', 'Sin cejas',
#        'Dibujos Presquemáticos', 'Con ojos negros', 'Sin cejas',
#        'Con ojos negros', 'Con ojos negros', 'Con ojos negros',
#        'Con ojos negros', 'Con ojos negros', 'Sin cejas',
#        'Con ojos negros', 'Con ojos negros'], dtype='<U22')

# %%
# Visualization of the predictions
def visualize_predictions(filenames, labels_true, labels_pred):
    numbers_to_display = min(149, len(filenames))
    num_cells = math.ceil(math.sqrt(numbers_to_display))
    plt.figure(figsize=(15, 15))

    for i in range(numbers_to_display):
        img = PILImage.open(filenames[i])
        img = remove_transparency(img)
        img_resized = img.resize((28, 28))
        img_gray = img_resized.convert('L')
        x = np.array(img_gray)

        y_true = labels_true[i]
        y_pred = labels_pred[i]

        color = 'green' if y_true == y_pred else 'red'

        plt.subplot(num_cells, num_cells, i + 1)
        plt.imshow(x, cmap='gray')
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.xlabel(f"{y_true} -->\n{y_pred}", color=color)

        # Add border color
        ax = plt.gca()
        for spine in ax.spines.values():
            spine.set_edgecolor(color)
            spine.set_linewidth(6)

    plt.subplots_adjust(hspace=1, wspace=0.5)
    plt.show()


# Visualize the results
visualize_predictions(filenames_test, labels_test, predicted_labels)

# %% [markdown]
# Calculamos el accuracy en el test set

# %%
# Calculate accuracy
accuracy = accuracy_score(labels_test, predicted_labels)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 0.88
